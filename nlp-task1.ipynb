# %%
import pandas as pd
import numpy as np
import torch

from torch import nn
from torch.utils.data import Dataset, DataLoader
import transformers
from transformers import AdamW, BertConfig

import re
import os
import random
import time
import tqdm
from sklearn.metrics import mean_squared_error
import seaborn as sns

# %%
train_df = pd.read_csv("../input/funnysemval/data/task-1/train.csv")
valid_df = pd.read_csv("../input/funnysemval/data/task-1/dev.csv")
test_df = pd.read_csv("../input/funnysemval/data/task-1/test_without_label.csv")

# %%
test_d_label = pd.read_csv("../input/funnysemval/data/task-1/test_with_label.csv")

# %%
train_df.head()
# Out:
#       id                                           original     edit  grades  \
# 0  14530  France is ‘ hunting down its citizens who join...    twins   10000
# 1  13034  Pentagon claims 2,000 % increase in Russian tr...  bowling   33110
# 2   8731  Iceland PM Calls Snap Vote as Pedophile Furor ...    party   22100
# 3     76  In an apparent first , Iran and Israel <engage...     slap   20000
# 4   6164  Trump was told weeks ago that Flynn misled <Vi...   school       0
#
#    meanGrade
# 0        0.2
# 1        1.6
# 2        1.0
# 3        0.4
# 4        0.0

# %%
valid_df.head()
# Out:
#       id                                           original      edit  grades  \
# 0   1723  Thousands of gay and bisexual <men/> convicted...     swans   22100
# 1  12736    Special <prosecutor/> appointed to Trump Russia      chef   21100
# 2  12274  Spanish police detain man and search Ripoll ad...     squad   21000
# 3   8823  N.Y. Times <reprimands/> reporter for sharing ...  applauds   32210
# 4   5087  Vladimir Putin Releases Video Simulation Of Ru...   balloon   11000
#
#    meanGrade
# 0        1.0
# 1        0.8
# 2        0.6
# 3        1.6
# 4        0.4

# %%
test_df.head()
# Out:
#       id                                           original    edit
# 0     36  The Latest : Election tally shows <Austria/> t...    Cars
# 1   2157  House Intel <Republicans/> Have Cleared Trump ...  onions
# 2   9385  Christmas Is Canceled : Nazareth ’s Muslim <Ma...   grump
# 3  14434  White House says Trump 's legal <team/> suppor...   bozos
# 4   9462  Election <analysts/> move Ryan seat toward Dem...  movers

# %%
def get_pair(sent_orig, edit_word):
    o = re.sub("[</>]", "", sent_orig)
    e = (sent_orig.split("<"))[0] + edit_word + (sent_orig.split(">"))[1]

    return e, o

# %%
train_df.head()
# Out:
#       id                                           original     edit  grades  \
# 0  14530  France is ‘ hunting down its citizens who join...    twins   10000
# 1  13034  Pentagon claims 2,000 % increase in Russian tr...  bowling   33110
# 2   8731  Iceland PM Calls Snap Vote as Pedophile Furor ...    party   22100
# 3     76  In an apparent first , Iran and Israel <engage...     slap   20000
# 4   6164  Trump was told weeks ago that Flynn misled <Vi...   school       0
#
#    meanGrade
# 0        0.2
# 1        1.6
# 2        1.0
# 3        0.4
# 4        0.0

# %%
train_df.loc[0]['original']
# Out:
# 'France is ‘ hunting down its citizens who joined <Isis/> ’ without trial in Iraq'

# %%
class SentencePair(Dataset):
    def __init__(self, dataframe, tokenizer, max_len=256):
        self.df = dataframe
        self.max_len = max_len
        self.tokenizer = tokenizer
        self.pad = self.tokenizer.pad_token_id
        self.cls = [self.tokenizer.cls_token_id]
        self.sep = [self.tokenizer.sep_token_id]

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        grade = torch.tensor(self.df["meanGrade"][idx],dtype=torch.float32)
        sent_e, sent_o = get_pair(self.df["original"][idx], self.df["edit"][idx])
        sent_e_tokens = (self.cls+ self.tokenizer.encode(sent_e, add_special_tokens=False)+ self.sep)
        sent_o_tokens = (self.tokenizer.encode(sent_o, add_special_tokens=False) + self.sep)
#         print(sent_e_tokens)
        token_type_ids = (torch.tensor([0] * len(sent_e_tokens) + [1] * (self.max_len - len(sent_e_tokens)))).long()
        attention_mask = torch.tensor([1] * (len(sent_o_tokens) + len(sent_e_tokens))+ [0] * (self.max_len - len(sent_o_tokens) - len(sent_e_tokens)))
        attention_mask = attention_mask.float()
        input_ids = torch.tensor(sent_o_tokens + sent_e_tokens)
#         print(input_ids)
#         print(attention_mask)
        if len(input_ids) < self.max_len:
            input_ids = torch.cat((input_ids,(torch.ones(self.max_len - len(input_ids)) * self.pad).long(),))
            token_type_ids = torch.cat((token_type_ids,(torch.ones(self.max_len - len(token_type_ids)) * self.pad).long(),))
        elif len(input_ids) > self.max_len:
            input_ids = input_ids[: self.max_len]
            token_type_ids = token_type_ids[: self.max_len]

        return input_ids, token_type_ids, attention_mask, grade

# %%
test_df['meanGrade']=[0]*len(test_df)


print(train_df.shape)
print(valid_df.shape)
print(test_df.shape)
# Out:
# (9652, 5)
# (2419, 5)
# (3024, 4)

# %%
test_df.reset_index(drop=True,inplace=True)

# %%
tokenizer = transformers.BertTokenizer.from_pretrained("bert-base-uncased")

train_df_ = SentencePair(train_df, tokenizer, max_len=256)


valid_df_ = SentencePair(valid_df, tokenizer, max_len=256)
test_df_ = SentencePair(test_df, tokenizer, max_len=256)

# %%
#  for i, data in enumerate(total_loader_1):
#         input_ids, token_type_ids, attention_mask, grade = data
#         print(input_ids,attention_mask)
#         break

train_loader=DataLoader(train_df_, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)



valid_loader=DataLoader(valid_df_, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

test_loader=DataLoader(test_df_, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple,DataLoader)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# %%
train_df.head()
# Out:
#       id                                           original     edit  grades  \
# 0  14530  France is ‘ hunting down its citizens who join...    twins   10000
# 1  13034  Pentagon claims 2,000 % increase in Russian tr...  bowling   33110
# 2   8731  Iceland PM Calls Snap Vote as Pedophile Furor ...    party   22100
# 3     76  In an apparent first , Iran and Israel <engage...     slap   20000
# 4   6164  Trump was told weeks ago that Flynn misled <Vi...   school       0
#
#    meanGrade
# 0        0.2
# 1        1.6
# 2        1.0
# 3        0.4
# 4        0.0

# %%
train_loader = to_device(train_loader,device)

valid_loader = to_device(valid_loader,device)

test_loader1 = to_device(test_loader,device)

# %%
model = transformers.BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=1).to(device,non_blocking=True)
# model = model.double()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import get_linear_schedule_with_warmup
optimizer = AdamW(model.parameters(),lr = 2e-5, eps = 1e-8)
total_steps = len(train_loader) * 2
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = 0,
                                            num_training_steps = total_steps)

# %%
# #Fine tuning Bert for our task
preds = []
loss_stat =[]

training_stat=[]
# model.eval()
epochs=30
count=0
start_time = time.time()
for epoch in range(epochs):
    total_loss=0
    count=0
    print('== Epoch {:} / {:} =='.format(epoch + 1, epochs))
    print('Training for this epoch')
    for i, data in enumerate(train_loader):
        model.zero_grad()
        input_ids, token_type_ids, attention_mask, grade = data
        outputs = model(
            input_ids=input_ids,
            labels=grade,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
        )
        loss, logits = outputs[:2]
        loss.backward()
        optimizer.step()
        scheduler.step()
        total_loss+=loss.item()
        loss_stat.append(loss)
        for logit in logits.reshape(-1):
            preds.append(logit.item())
        count+=1
        print("Batch done out of 302:",count)
    
    avg_training_loss=total_loss/len(train_loader)
    print("Average training loss:",avg_training_loss)
    
    #Validation==============================
    #Uncomment this for validation loss 
    ## WARNING-> It will take lot of time 
    print("running validation")
    valid_preds=[]
    val_loss=0
    with torch.no_grad():
        for i, data in enumerate(valid_loader):
            input_ids, token_type_ids, attention_mask, grade = data
            outputs = model(
                input_ids=input_ids,
                labels=grade,
                attention_mask=attention_mask,
                token_type_ids=token_type_ids,
            )
            loss, logits = outputs[:2]
            val_loss+=loss.item()
            for logit in logits.reshape(-1):
                valid_preds.append(logit.item())
        training_stat.append(
        {
            'epoch': epoch + 1,
            'Training Loss': avg_training_loss,
            'Valid. Loss': val_loss/len(valid_loader),
        }
        
    )
        print("--- %s seconds ---" % (time.time() - start_time))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# == Epoch 1 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.3340082767092629
# running validation
# --- 247.48162484169006 seconds ---
# == Epoch 2 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.220406575930237
# running validation
# --- 495.1277618408203 seconds ---
# == Epoch 3 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.1701761403719321
# running validation
# --- 742.7881631851196 seconds ---
# == Epoch 4 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.1701761403719321
# running validation
# --- 990.4264497756958 seconds ---
# == Epoch 5 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.1701761403719321
# running validation
# --- 1238.196989774704 seconds ---
# == Epoch 6 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# ...
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.1701761403719321
# running validation
# --- 7183.867833614349 seconds ---
# == Epoch 30 / 30 ==
# Training for this epoch
# Batch done out of 302: 1
# Batch done out of 302: 2
# Batch done out of 302: 3
# Batch done out of 302: 4
# Batch done out of 302: 5
# Batch done out of 302: 6
# Batch done out of 302: 7
# Batch done out of 302: 8
# Batch done out of 302: 9
# Batch done out of 302: 10
# Batch done out of 302: 11
# Batch done out of 302: 12
# Batch done out of 302: 13
# Batch done out of 302: 14
# Batch done out of 302: 15
# Batch done out of 302: 16
# Batch done out of 302: 17
# Batch done out of 302: 18
# Batch done out of 302: 19
# Batch done out of 302: 20
# Batch done out of 302: 21
# Batch done out of 302: 22
# Batch done out of 302: 23
# Batch done out of 302: 24
# Batch done out of 302: 25
# Batch done out of 302: 26
# Batch done out of 302: 27
# Batch done out of 302: 28
# Batch done out of 302: 29
# Batch done out of 302: 30
# Batch done out of 302: 31
# Batch done out of 302: 32
# Batch done out of 302: 33
# Batch done out of 302: 34
# Batch done out of 302: 35
# Batch done out of 302: 36
# Batch done out of 302: 37
# Batch done out of 302: 38
# Batch done out of 302: 39
# Batch done out of 302: 40
# Batch done out of 302: 41
# Batch done out of 302: 42
# Batch done out of 302: 43
# Batch done out of 302: 44
# Batch done out of 302: 45
# Batch done out of 302: 46
# Batch done out of 302: 47
# Batch done out of 302: 48
# Batch done out of 302: 49
# Batch done out of 302: 50
# Batch done out of 302: 51
# Batch done out of 302: 52
# Batch done out of 302: 53
# Batch done out of 302: 54
# Batch done out of 302: 55
# Batch done out of 302: 56
# Batch done out of 302: 57
# Batch done out of 302: 58
# Batch done out of 302: 59
# Batch done out of 302: 60
# Batch done out of 302: 61
# Batch done out of 302: 62
# Batch done out of 302: 63
# Batch done out of 302: 64
# Batch done out of 302: 65
# Batch done out of 302: 66
# Batch done out of 302: 67
# Batch done out of 302: 68
# Batch done out of 302: 69
# Batch done out of 302: 70
# Batch done out of 302: 71
# Batch done out of 302: 72
# Batch done out of 302: 73
# Batch done out of 302: 74
# Batch done out of 302: 75
# Batch done out of 302: 76
# Batch done out of 302: 77
# Batch done out of 302: 78
# Batch done out of 302: 79
# Batch done out of 302: 80
# Batch done out of 302: 81
# Batch done out of 302: 82
# Batch done out of 302: 83
# Batch done out of 302: 84
# Batch done out of 302: 85
# Batch done out of 302: 86
# Batch done out of 302: 87
# Batch done out of 302: 88
# Batch done out of 302: 89
# Batch done out of 302: 90
# Batch done out of 302: 91
# Batch done out of 302: 92
# Batch done out of 302: 93
# Batch done out of 302: 94
# Batch done out of 302: 95
# Batch done out of 302: 96
# Batch done out of 302: 97
# Batch done out of 302: 98
# Batch done out of 302: 99
# Batch done out of 302: 100
# Batch done out of 302: 101
# Batch done out of 302: 102
# Batch done out of 302: 103
# Batch done out of 302: 104
# Batch done out of 302: 105
# Batch done out of 302: 106
# Batch done out of 302: 107
# Batch done out of 302: 108
# Batch done out of 302: 109
# Batch done out of 302: 110
# Batch done out of 302: 111
# Batch done out of 302: 112
# Batch done out of 302: 113
# Batch done out of 302: 114
# Batch done out of 302: 115
# Batch done out of 302: 116
# Batch done out of 302: 117
# Batch done out of 302: 118
# Batch done out of 302: 119
# Batch done out of 302: 120
# Batch done out of 302: 121
# Batch done out of 302: 122
# Batch done out of 302: 123
# Batch done out of 302: 124
# Batch done out of 302: 125
# Batch done out of 302: 126
# Batch done out of 302: 127
# Batch done out of 302: 128
# Batch done out of 302: 129
# Batch done out of 302: 130
# Batch done out of 302: 131
# Batch done out of 302: 132
# Batch done out of 302: 133
# Batch done out of 302: 134
# Batch done out of 302: 135
# Batch done out of 302: 136
# Batch done out of 302: 137
# Batch done out of 302: 138
# Batch done out of 302: 139
# Batch done out of 302: 140
# Batch done out of 302: 141
# Batch done out of 302: 142
# Batch done out of 302: 143
# Batch done out of 302: 144
# Batch done out of 302: 145
# Batch done out of 302: 146
# Batch done out of 302: 147
# Batch done out of 302: 148
# Batch done out of 302: 149
# Batch done out of 302: 150
# Batch done out of 302: 151
# Batch done out of 302: 152
# Batch done out of 302: 153
# Batch done out of 302: 154
# Batch done out of 302: 155
# Batch done out of 302: 156
# Batch done out of 302: 157
# Batch done out of 302: 158
# Batch done out of 302: 159
# Batch done out of 302: 160
# Batch done out of 302: 161
# Batch done out of 302: 162
# Batch done out of 302: 163
# Batch done out of 302: 164
# Batch done out of 302: 165
# Batch done out of 302: 166
# Batch done out of 302: 167
# Batch done out of 302: 168
# Batch done out of 302: 169
# Batch done out of 302: 170
# Batch done out of 302: 171
# Batch done out of 302: 172
# Batch done out of 302: 173
# Batch done out of 302: 174
# Batch done out of 302: 175
# Batch done out of 302: 176
# Batch done out of 302: 177
# Batch done out of 302: 178
# Batch done out of 302: 179
# Batch done out of 302: 180
# Batch done out of 302: 181
# Batch done out of 302: 182
# Batch done out of 302: 183
# Batch done out of 302: 184
# Batch done out of 302: 185
# Batch done out of 302: 186
# Batch done out of 302: 187
# Batch done out of 302: 188
# Batch done out of 302: 189
# Batch done out of 302: 190
# Batch done out of 302: 191
# Batch done out of 302: 192
# Batch done out of 302: 193
# Batch done out of 302: 194
# Batch done out of 302: 195
# Batch done out of 302: 196
# Batch done out of 302: 197
# Batch done out of 302: 198
# Batch done out of 302: 199
# Batch done out of 302: 200
# Batch done out of 302: 201
# Batch done out of 302: 202
# Batch done out of 302: 203
# Batch done out of 302: 204
# Batch done out of 302: 205
# Batch done out of 302: 206
# Batch done out of 302: 207
# Batch done out of 302: 208
# Batch done out of 302: 209
# Batch done out of 302: 210
# Batch done out of 302: 211
# Batch done out of 302: 212
# Batch done out of 302: 213
# Batch done out of 302: 214
# Batch done out of 302: 215
# Batch done out of 302: 216
# Batch done out of 302: 217
# Batch done out of 302: 218
# Batch done out of 302: 219
# Batch done out of 302: 220
# Batch done out of 302: 221
# Batch done out of 302: 222
# Batch done out of 302: 223
# Batch done out of 302: 224
# Batch done out of 302: 225
# Batch done out of 302: 226
# Batch done out of 302: 227
# Batch done out of 302: 228
# Batch done out of 302: 229
# Batch done out of 302: 230
# Batch done out of 302: 231
# Batch done out of 302: 232
# Batch done out of 302: 233
# Batch done out of 302: 234
# Batch done out of 302: 235
# Batch done out of 302: 236
# Batch done out of 302: 237
# Batch done out of 302: 238
# Batch done out of 302: 239
# Batch done out of 302: 240
# Batch done out of 302: 241
# Batch done out of 302: 242
# Batch done out of 302: 243
# Batch done out of 302: 244
# Batch done out of 302: 245
# Batch done out of 302: 246
# Batch done out of 302: 247
# Batch done out of 302: 248
# Batch done out of 302: 249
# Batch done out of 302: 250
# Batch done out of 302: 251
# Batch done out of 302: 252
# Batch done out of 302: 253
# Batch done out of 302: 254
# Batch done out of 302: 255
# Batch done out of 302: 256
# Batch done out of 302: 257
# Batch done out of 302: 258
# Batch done out of 302: 259
# Batch done out of 302: 260
# Batch done out of 302: 261
# Batch done out of 302: 262
# Batch done out of 302: 263
# Batch done out of 302: 264
# Batch done out of 302: 265
# Batch done out of 302: 266
# Batch done out of 302: 267
# Batch done out of 302: 268
# Batch done out of 302: 269
# Batch done out of 302: 270
# Batch done out of 302: 271
# Batch done out of 302: 272
# Batch done out of 302: 273
# Batch done out of 302: 274
# Batch done out of 302: 275
# Batch done out of 302: 276
# Batch done out of 302: 277
# Batch done out of 302: 278
# Batch done out of 302: 279
# Batch done out of 302: 280
# Batch done out of 302: 281
# Batch done out of 302: 282
# Batch done out of 302: 283
# Batch done out of 302: 284
# Batch done out of 302: 285
# Batch done out of 302: 286
# Batch done out of 302: 287
# Batch done out of 302: 288
# Batch done out of 302: 289
# Batch done out of 302: 290
# Batch done out of 302: 291
# Batch done out of 302: 292
# Batch done out of 302: 293
# Batch done out of 302: 294
# Batch done out of 302: 295
# Batch done out of 302: 296
# Batch done out of 302: 297
# Batch done out of 302: 298
# Batch done out of 302: 299
# Batch done out of 302: 300
# Batch done out of 302: 301
# Batch done out of 302: 302
# Average training loss: 0.1701761403719321
# running validation
# --- 7431.602915525436 seconds ---
# --- 7431.603213310242 seconds ---

# %%
test_1 = []
count=0
with torch.no_grad():
    for i, data in enumerate(test_loader1):
        input_ids, token_type_ids, attention_mask, grade = data
        outputs = model(
            input_ids=input_ids,
            labels=grade,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
        )
        _, logits = outputs[:2]

        for logit in logits.reshape(-1):
            test_1.append(logit.item())
        count+=1
        print("Batch done out of 95:",count)
# Out:
# Batch done out of 95: 1
# Batch done out of 95: 2
# Batch done out of 95: 3
# Batch done out of 95: 4
# Batch done out of 95: 5
# Batch done out of 95: 6
# Batch done out of 95: 7
# Batch done out of 95: 8
# Batch done out of 95: 9
# Batch done out of 95: 10
# Batch done out of 95: 11
# Batch done out of 95: 12
# Batch done out of 95: 13
# Batch done out of 95: 14
# Batch done out of 95: 15
# Batch done out of 95: 16
# Batch done out of 95: 17
# Batch done out of 95: 18
# Batch done out of 95: 19
# Batch done out of 95: 20
# Batch done out of 95: 21
# Batch done out of 95: 22
# Batch done out of 95: 23
# Batch done out of 95: 24
# Batch done out of 95: 25
# Batch done out of 95: 26
# Batch done out of 95: 27
# Batch done out of 95: 28
# Batch done out of 95: 29
# Batch done out of 95: 30
# Batch done out of 95: 31
# Batch done out of 95: 32
# Batch done out of 95: 33
# Batch done out of 95: 34
# Batch done out of 95: 35
# Batch done out of 95: 36
# Batch done out of 95: 37
# Batch done out of 95: 38
# Batch done out of 95: 39
# Batch done out of 95: 40
# Batch done out of 95: 41
# Batch done out of 95: 42
# Batch done out of 95: 43
# Batch done out of 95: 44
# Batch done out of 95: 45
# Batch done out of 95: 46
# Batch done out of 95: 47
# Batch done out of 95: 48
# Batch done out of 95: 49
# Batch done out of 95: 50
# Batch done out of 95: 51
# Batch done out of 95: 52
# Batch done out of 95: 53
# Batch done out of 95: 54
# Batch done out of 95: 55
# Batch done out of 95: 56
# Batch done out of 95: 57
# Batch done out of 95: 58
# Batch done out of 95: 59
# Batch done out of 95: 60
# Batch done out of 95: 61
# Batch done out of 95: 62
# Batch done out of 95: 63
# Batch done out of 95: 64
# Batch done out of 95: 65
# Batch done out of 95: 66
# Batch done out of 95: 67
# Batch done out of 95: 68
# Batch done out of 95: 69
# Batch done out of 95: 70
# Batch done out of 95: 71
# Batch done out of 95: 72
# Batch done out of 95: 73
# Batch done out of 95: 74
# Batch done out of 95: 75
# Batch done out of 95: 76
# Batch done out of 95: 77
# Batch done out of 95: 78
# Batch done out of 95: 79
# Batch done out of 95: 80
# Batch done out of 95: 81
# Batch done out of 95: 82
# Batch done out of 95: 83
# Batch done out of 95: 84
# Batch done out of 95: 85
# Batch done out of 95: 86
# Batch done out of 95: 87
# Batch done out of 95: 88
# Batch done out of 95: 89
# Batch done out of 95: 90
# Batch done out of 95: 91
# Batch done out of 95: 92
# Batch done out of 95: 93
# Batch done out of 95: 94
# Batch done out of 95: 95

# %%
print(mean_squared_error(test_d_label['meanGrade'].tolist(),test_1,squared=False))
# Out:
# 0.5416581637756431

# %%
training_loss = []
valid_loss = []
for stat in training_stat:
    training_loss.append(stat['Training Loss'])
    valid_loss.append(stat['Valid. Loss'])
sns.lineplot(data=valid_loss)
sns.lineplot(data=training_loss)
# Out:
# <AxesSubplot:>

# %%
import pickle 
with open('final_task1_preds.pickle', 'wb') as handle:
    pickle.dump(model , handle, protocol=pickle.HIGHEST_PROTOCOL)
